# %%
# This is the code used for creating, training and validating the CNN-Models

# %%
# runs with tf 1.12-GPU
# here all the required modules are imported 

import PIL
from PIL import Image
import numpy as np
import os 
import random
import time 
import matplotlib.pyplot as plt
import pydot

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, plot_confusion_matrix
from keras.models import Sequential
from keras.optimizers import SGD, Adam
from keras.utils import to_categorical, plot_model
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from keras.models import load_model
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras import backend as K
from keras import regularizers
from imblearn.over_sampling import RandomOverSampler

# %%
# This block is used to load the data into RAM

# list of dirs containing the data - one for the porosity labeled data and one for the no_porosity_labeled data
dirs = [ '/media/jan/Volume_big/datasets/Square_data_Gridsize_220_100µm_corrected/3layer/generated_ds/mixed/porosity',
         '/media/jan/Volume_big/datasets/Square_data_Gridsize_220_100µm_corrected/3layer/generated_ds/mixed/no_porosity']


length = 4632 # number of samples per category 
random_seed = 22 
image_paths = []
show_time = True  # can be toggled to show the time for loading the data into RAM 

if show_time:
    start_time = time.time()

# creating a list with paths of all files in each folder     
for d in dirs: 
    cur_paths = []
    for path in os.listdir(d):
        full_path = os.path.join(d,path)  # adding the full path as the label is stored in the path
        cur_paths.append(full_path)
    
    # randomly shuffling the created list and cutting it to the desired length
    # added to the code for being able to deal with non pre-balanced data sets - if folders both have same length nothing happens at this point
    random.seed(random_seed) 
    random.shuffle(cur_paths)
    cur_paths = cur_paths[:length] 
    
    image_paths.append(cur_paths) # appending the cut list to a new list containing all the final paths        

image_paths = [val for sublist in image_paths for val in sublist] # getting the seperate image paths out of the list
random.seed(random_seed)
random.shuffle(image_paths) # randomly shuffling the list containing the final paths

labels = []
data = []
# generating the label from the second last part of path for every element in the list and adding it to labels-list
# loading the np array, resizing and storing it to data-list

for path in image_paths:
    label = path.split(os.path.sep)[-2] # here it is 'porosity' or 'no_porosity' 
    # additionally to the pure label the whole path is stored to make a traceback of model_behaviour possible 
    # the number needs to be changed according to the link to output something like '/porosity/ZP...'
    labels.append([label,path[97:]])
    array = np.load(path)
    # img = Image.fromarray(array)   # could be added if resizing operation was necessary
    # img = img.resize((128, 128), PIL.Image.LANCZOS)
    # array_resized = np.array(img)
    data.append(array)
    
# scale the raw pixel intensities to the range [0, 1] and making arrays out of lists for sklearn-functions
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)

# splitting data and labels in train, valid and test set in ratio (0.75, 0.125, 0.125)
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.25, random_state=42)
(validX, testX, validY, testY) = train_test_split(testX, testY, test_size=0.5, random_state=42)

# at this point the lables are an array with entries like ['porosity', '/porosity/ZP3_Slice00690_x:1_y:1.npy']
# the following part splits up the array to generate labels and also a list with the full paths 

trainY_list = []
trainY_path = []
testY_list = []
testY_path = []
validY_list = []
validY_path = []

for row in trainY:
    trainY_list.append(row[0])
    trainY_path.append(row[1]) 
trainY = np.array(trainY_list)
trainY_path = np.array(trainY_path)

for row in testY:
    testY_list.append(row[0])
    testY_path.append(row[1]) 
testY = np.array(testY_list)
testY_path = np.array(testY_path)

for row in validY:
    validY_list.append(row[0])
    validY_path.append(row[1]) 
validY = np.array(validY_list)
validY_path = np.array(validY_path)

# the LabelBinarizer module is used to one hot encode the labels 
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)
validY = lb.transform(validY)

# now the Labels are arrays containing either a '0' for 'no_porosity' or a '1' for 'porosity'
if show_time:
    print(time.time()-start_time)
    
# the shapes of the different data sets are printed  
print('shape training dataset: ' + str(trainX.shape))
print('shape validation dataset: ' + str(validX.shape))
print('shape test dataset: ' + str(testX.shape))
# Out:
# 167.26107811927795

# %%
# in case the 1 layer data is used it needs to be reshaped so it can be processed by the NN 
trainX = trainX.reshape(trainX.shape[0], trainX.shape[1], trainX.shape[2], 1)
validX = validX.reshape(validX.shape[0], validX.shape[1], validX.shape[2], 1)
testX = testX.reshape(testX.shape[0], testX.shape[1], testX.shape[2], 1)

# %%
# this is a function to keep the code for building the models clean 

def add_conv_module (n_filters, n_layers, regularization, kernel_initalization, activation, Batch_normalization = False, max_pool = False):
    
    # looping through the defined number of layers and adding Convolutional layers
    # in all the models used in the work the kernel size was (3,3) and same-padding was used 
    for i in range (n_layers):
        model.add(Conv2D(filters=n_filters,kernel_size=(3,3),padding="same", activation=activation,
                         kernel_initializer = kernel_initalization, kernel_regularizer = regularization))
        if Batch_normalization == True:
            model.add(BatchNormalization())
    
    # if desired a max pooling layer can be added to the end of block 
    if max_pool == True:
        model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))      
        if Batch_normalization == True:
            model.add(BatchNormalization())

# %%
# Model_building
# This part needs to be adjusted depending on the desired architecture of the model


model_name = "3layer_100µm_mixed_2x16_2x32_3x64"

# defining parameters
regul = regularizers.l2(0.001)
kernel_inil = "he_normal"
model = Sequential()       
inputShape = (220, 220, 3)
activation = "relu"
dropout_rate = 0.2 #4 #3

model = Sequential()

# This is the feature extractor part of the model 
# first conv_layer (special because of Input-Shape)
model.add(Conv2D(input_shape=inputShape, filters=16,kernel_size=(3,3),padding="same", activation=activation,
                         kernel_initializer = kernel_inil, kernel_regularizer = regul))
model.add(BatchNormalization())
# further conv_layers
add_conv_module(n_filters = 16, n_layers= 1, regularization = regul, kernel_initalization = kernel_inil,
                activation = activation, Batch_normalization = True, max_pool = True)

add_conv_module(n_filters = 32, n_layers= 2, regularization = regul, kernel_initalization = kernel_inil,
                activation = activation, Batch_normalization = True, max_pool = True)

add_conv_module(n_filters = 64, n_layers= 3, regularization = regul, kernel_initalization = kernel_inil,
                activation = activation, Batch_normalization = True, max_pool = True)

model.add(Flatten())

# This is the classifier part of the model 
model.add(Dense(units=16,activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))
model.add(Dense(units=16,activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))
model.add(Dense(units = 1,activation="sigmoid")) 

# building the model and showing the summary
model.build()
model.summary()

# %%
# Here the number of epochs, the Batchsize, the optimizer and the Data Augmentation steps are defined 
# Finally the model is compiled 

EPOCHS = 500
BS = 32
opt = SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov = True)     #'Adam' # should be the default optimizer with standard setting according to Hands-On-ML
aug = ImageDataGenerator(vertical_flip= True,horizontal_flip=True) # data is randomly flipped horizontally as well as vertically to prevent the NN from learning local dependecies aug = ImageDataGenerator(vertical_flip= True,horizontal_flip=True) # data is randomly flipped horizontally as well as vertically to prevent the NN from learning local dependecies 

model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

# %%
# Here the actual training process is started 

# first a file is defined where the model_weights are store
filepath="model_weights/{}_weights.best.hdf5".format(model_name)

# the checkpoint saved the model weights whenever the validation loss decreases 
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# EarlyStopping is set up to stop training when validation loss isn't decreasing for a number of epochs defindes by the patience parameter
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

# checkpoint and Early stopping are added to the callbacks list 
callbacks_list = [checkpoint,es]

# Thbe model is fit to the training data and validated with the validation data 
J = model.fit_generator(aug.flow(trainX, trainY, batch_size=BS),validation_data=(validX, validY), steps_per_epoch=len(trainX) // BS,epochs=EPOCHS,callbacks=callbacks_list)
# Out:
# Epoch 1/200
# 217/217 [==============================] - 23s 108ms/step - loss: 1.2794 - acc: 0.5166 - val_loss: 1.2299 - val_acc: 0.4965
#
# Epoch 00001: val_loss improved from inf to 1.22991, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 2/200
# 217/217 [==============================] - 19s 90ms/step - loss: 1.2059 - acc: 0.5079 - val_loss: 1.1791 - val_acc: 0.5259
#
# Epoch 00002: val_loss improved from 1.22991 to 1.17909, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 3/200
# 217/217 [==============================] - 19s 90ms/step - loss: 1.1598 - acc: 0.5204 - val_loss: 1.1403 - val_acc: 0.5345
#
# Epoch 00003: val_loss improved from 1.17909 to 1.14034, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 4/200
# 217/217 [==============================] - 20s 91ms/step - loss: 1.1203 - acc: 0.5219 - val_loss: 1.0988 - val_acc: 0.5337
#
# Epoch 00004: val_loss improved from 1.14034 to 1.09883, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 5/200
# 217/217 [==============================] - 20s 91ms/step - loss: 1.0846 - acc: 0.5298 - val_loss: 1.0630 - val_acc: 0.5535
#
# Epoch 00005: val_loss improved from 1.09883 to 1.06302, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 6/200
# 217/217 [==============================] - 20s 91ms/step - loss: 1.0503 - acc: 0.5337 - val_loss: 1.0303 - val_acc: 0.5535
#
# Epoch 00006: val_loss improved from 1.06302 to 1.03028, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 7/200
# 217/217 [==============================] - 20s 91ms/step - loss: 1.0208 - acc: 0.5343 - val_loss: 1.0057 - val_acc: 0.5527
#
# Epoch 00007: val_loss improved from 1.03028 to 1.00566, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 8/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.9920 - acc: 0.5390 - val_loss: 0.9834 - val_acc: 0.5354
#
# Epoch 00008: val_loss improved from 1.00566 to 0.98336, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 9/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.9652 - acc: 0.5452 - val_loss: 0.9561 - val_acc: 0.5380
#
# Epoch 00009: val_loss improved from 0.98336 to 0.95615, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 10/200
# 217/217 [==============================] - 20s 92ms/step - loss: 0.9400 - acc: 0.5552 - val_loss: 0.9301 - val_acc: 0.5509
#
# Epoch 00010: val_loss improved from 0.95615 to 0.93012, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 11/200
# 217/217 [==============================] - 20s 92ms/step - loss: 0.9139 - acc: 0.5675 - val_loss: 0.9211 - val_acc: 0.5630
#
# Epoch 00011: val_loss improved from 0.93012 to 0.92107, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 12/200
# 217/217 [==============================] - 20s 92ms/step - loss: 0.8983 - acc: 0.5611 - val_loss: 0.8824 - val_acc: 0.5855
#
# Epoch 00012: val_loss improved from 0.92107 to 0.88236, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 13/200
# 217/217 [==============================] - 20s 92ms/step - loss: 0.8772 - acc: 0.5766 - val_loss: 0.8685 - val_acc: 0.5708
#
# Epoch 00013: val_loss improved from 0.88236 to 0.86851, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 14/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.8574 - acc: 0.5791 - val_loss: 0.8622 - val_acc: 0.5501
#
# Epoch 00014: val_loss improved from 0.86851 to 0.86218, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 15/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.8445 - acc: 0.5678 - val_loss: 0.8467 - val_acc: 0.5648
#
# Epoch 00015: val_loss improved from 0.86218 to 0.84666, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 16/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.8299 - acc: 0.5783 - val_loss: 0.8280 - val_acc: 0.5898
#
# Epoch 00016: val_loss improved from 0.84666 to 0.82798, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 17/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.8149 - acc: 0.5922 - val_loss: 0.8172 - val_acc: 0.5682
#
# Epoch 00017: val_loss improved from 0.82798 to 0.81719, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 18/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.8015 - acc: 0.5939 - val_loss: 0.8494 - val_acc: 0.5190
#
# Epoch 00018: val_loss did not improve from 0.81719
# Epoch 19/200
# 217/217 [==============================] - 20s 92ms/step - loss: 0.7922 - acc: 0.5916 - val_loss: 0.7993 - val_acc: 0.5803
#
# Epoch 00019: val_loss improved from 0.81719 to 0.79935, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 20/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.7865 - acc: 0.5854 - val_loss: 0.7931 - val_acc: 0.5907
#
# Epoch 00020: val_loss improved from 0.79935 to 0.79307, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 21/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.7708 - acc: 0.6025 - val_loss: 0.7905 - val_acc: 0.5803
#
# Epoch 00021: val_loss improved from 0.79307 to 0.79052, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 22/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.7623 - acc: 0.6086 - val_loss: 0.7745 - val_acc: 0.5769
#
# Epoch 00022: val_loss improved from 0.79052 to 0.77453, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 23/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.7529 - acc: 0.6105 - val_loss: 0.7700 - val_acc: 0.5924
#
# Epoch 00023: val_loss improved from 0.77453 to 0.76999, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 24/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.7419 - acc: 0.6197 - val_loss: 0.7810 - val_acc: 0.5743
#
# Epoch 00024: val_loss did not improve from 0.76999
# Epoch 25/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.7300 - acc: 0.6358 - val_loss: 0.7694 - val_acc: 0.5915
#
# Epoch 00025: val_loss improved from 0.76999 to 0.76944, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 26/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.7335 - acc: 0.6211 - val_loss: 0.7728 - val_acc: 0.5622
#
# Epoch 00026: val_loss did not improve from 0.76944
# Epoch 27/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.7272 - acc: 0.6285 - val_loss: 0.8717 - val_acc: 0.5699
#
# Epoch 00027: val_loss did not improve from 0.76944
# Epoch 28/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.7214 - acc: 0.6272 - val_loss: 0.7669 - val_acc: 0.5794
#
# Epoch 00028: val_loss improved from 0.76944 to 0.76692, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 29/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.7238 - acc: 0.6265 - val_loss: 0.7655 - val_acc: 0.5786
#
# Epoch 00029: val_loss improved from 0.76692 to 0.76550, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 30/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.7150 - acc: 0.6344 - val_loss: 0.7497 - val_acc: 0.5924
#
# Epoch 00030: val_loss improved from 0.76550 to 0.74971, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 31/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.7023 - acc: 0.6452 - val_loss: 0.7696 - val_acc: 0.5803
#
# Epoch 00031: val_loss did not improve from 0.74971
# Epoch 32/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.6902 - acc: 0.6548 - val_loss: 0.7537 - val_acc: 0.5872
# Epoch 00032: val_loss did not improve from 0.74971
# Epoch 33/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.6841 - acc: 0.6610 - val_loss: 0.7532 - val_acc: 0.6097
#
# Epoch 00033: val_loss did not improve from 0.74971
# Epoch 34/200
# 217/217 [==============================] - 20s 92ms/step - loss: 0.6895 - acc: 0.6590 - val_loss: 0.7471 - val_acc: 0.6123
#
# Epoch 00034: val_loss improved from 0.74971 to 0.74712, saving model to model_weights/3layer_100µm_mixed_2x16_2x32_3x64_weights.best.hdf5
# Epoch 35/200
# 217/217 [==============================] - 20s 90ms/step - loss: 0.6752 - acc: 0.6694 - val_loss: 0.7590 - val_acc: 0.5881
#
# Epoch 00035: val_loss did not improve from 0.74712
# Epoch 36/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.6645 - acc: 0.6781 - val_loss: 0.7787 - val_acc: 0.5881
#
# Epoch 00036: val_loss did not improve from 0.74712
# Epoch 37/200
# 217/217 [==============================] - 19s 89ms/step - loss: 0.6693 - acc: 0.6770 - val_loss: 0.7649 - val_acc: 0.6071
#
# Epoch 00037: val_loss did not improve from 0.74712
# Epoch 38/200
# 217/217 [==============================] - 19s 89ms/step - loss: 0.7042 - acc: 0.6503 - val_loss: 0.7662 - val_acc: 0.5794
#
# Epoch 00038: val_loss did not improve from 0.74712
# Epoch 39/200
# 217/217 [==============================] - 20s 90ms/step - loss: 0.6657 - acc: 0.6853 - val_loss: 0.8071 - val_acc: 0.5777
#
# Epoch 00039: val_loss did not improve from 0.74712
# Epoch 40/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.6712 - acc: 0.6823 - val_loss: 0.7714 - val_acc: 0.6019
#
# Epoch 00040: val_loss did not improve from 0.74712
# Epoch 41/200
# 217/217 [==============================] - 20s 91ms/step - loss: 0.6446 - acc: 0.6954 - val_loss: 0.7553 - val_acc: 0.6218
#
# Epoch 00041: val_loss did not improve from 0.74712
# Epoch 42/200
# 217/217 [==============================] - 20s 92ms/step - loss: 0.6405 - acc: 0.7046 - val_loss: 0.7628 - val_acc: 0.6304
#
# Epoch 00042: val_loss did not improve from 0.74712
# Epoch 43/200
# 217/217 [==============================] - 20s 92ms/step - loss: 0.6457 - acc: 0.7026 - val_loss: 0.7803 - val_acc: 0.6054
#
# Epoch 00043: val_loss did not improve from 0.74712
# Epoch 44/200
# 217/217 [==============================] - 20s 92ms/step - loss: 0.6331 - acc: 0.7173 - val_loss: 0.7912 - val_acc: 0.5786
#
# Epoch 00044: val_loss did not improve from 0.74712
# Epoch 00044: early stopping

# %%
# This block is used for plotting the learning curve

N = np.arange(0,44) # the number needs to be adjusted depending on the 
plt.style.use("ggplot")
plt.figure
plt.plot(N, J.history["loss"], label="train_loss")
plt.plot(N, J.history["val_loss"], label="val_loss")
plt.plot(N, J.history["acc"], label="train_acc")
plt.plot(N, J.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy ({})".format(model_name))
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()

# %%
# This block is used for creating the confusion matrix and the classification report with the calculated metrics

# As a first step the models best weights are loaded before making the predicitions on the so far held back test set
model.load_weights("model_weights/{}_weights.best.hdf5".format(model_name))

# here the model predicts the class based on the data
model_predictions = model.predict(testX)
model_predictions =(model_predictions>0.5)

cm = confusion_matrix(testY, model_predictions)
cr = classification_report(testY, model_predictions)


print(model_name)
print(cm)
print(cr)
# Out:
# 3layer_100µm_mixed_2x16_2x32_3x64
# [[368 210]
#  [264 316]]
#               precision    recall  f1-score   support
#
#            0       0.58      0.64      0.61       578
#            1       0.60      0.54      0.57       580
#
#     accuracy                           0.59      1158
#    macro avg       0.59      0.59      0.59      1158
# weighted avg       0.59      0.59      0.59      1158

# %%
model.save('trained_models_for_work/100µm/Standardparameters/{}.h5'.format(model_name))
